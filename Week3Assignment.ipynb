# %%
#@ IMPORTING LIBRARIES AND DEPENDENCIES:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mutual_info_score
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

# %%
#@ IMPORTING DATASET:
PATH = "./chapter-02-car-price_data.csv"
select_cols = ["Make", "Model", "Year", "Engine HP", "Engine Cylinders", "Transmission Type", "Vehicle Style", 
               "highway MPG", "city mpg", "MSRP"]
df = pd.read_csv(PATH, usecols=select_cols)

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type  Vehicle Style  highway MPG  city mpg   MSRP
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg   msrp
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_hp          11845 non-null  float64
#  4   engine_cylinders   11884 non-null  float64
#  5   transmission_type  11914 non-null  object
#  6   vehicle_style      11914 non-null  object
#  7   highway_mpg        11914 non-null  int64
#  8   city_mpg           11914 non-null  int64
#  9   msrp               11914 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 930.9+ KB

# %%
df['transmission_type'].mode()
# Out:
# 0    AUTOMATIC
# Name: transmission_type, dtype: object

# %%
df.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# msrp                  0
# dtype: int64

# %%
df.fillna('0', inplace = True)

# %%
df.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# msrp                 0
# dtype: int64

# %%
df.rename(columns = {'msrp':'price'}, inplace = True)

# %%
df
# Out:
#           make       model  year engine_hp engine_cylinders transmission_type  \
# 0          BMW  1 Series M  2011     335.0              6.0            MANUAL
# 1          BMW    1 Series  2011     300.0              6.0            MANUAL
# 2          BMW    1 Series  2011     300.0              6.0            MANUAL
# 3          BMW    1 Series  2011     230.0              6.0            MANUAL
# 4          BMW    1 Series  2011     230.0              6.0            MANUAL
# ...        ...         ...   ...       ...              ...               ...
# 11909    Acura         ZDX  2012     300.0              6.0         AUTOMATIC
# 11910    Acura         ZDX  2012     300.0              6.0         AUTOMATIC
# 11911    Acura         ZDX  2012     300.0              6.0         AUTOMATIC
# 11912    Acura         ZDX  2013     300.0              6.0         AUTOMATIC
# 11913  Lincoln      Zephyr  2006     221.0              6.0         AUTOMATIC
#
#        vehicle_style  highway_mpg  city_mpg  price
# 0              Coupe           26        19  46135
# 1        Convertible           28        19  40650
# 2              Coupe           28        20  36350
# 3              Coupe           28        18  29450
# 4        Convertible           28        18  34500
# ...              ...          ...       ...    ...
# 11909  4dr Hatchback           23        16  46120
# 11910  4dr Hatchback           23        16  56670
# 11911  4dr Hatchback           23        16  50620
# 11912  4dr Hatchback           23        16  50920
# 11913          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# price                0
# dtype: int64

# %%
numericfeatures_df = df.copy()
numerifeatures_df = df.drop(["make","model","transmission_type","vehicle_style"],axis = 1)

# %%
numericfeatures_df.describe()
# Out:
#                year   highway_mpg      city_mpg         price
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean    2010.384338     26.637485     19.733255  4.059474e+04
# std        7.579740      8.863001      8.987798  6.010910e+04
# min     1990.000000     12.000000      7.000000  2.000000e+03
# 25%     2007.000000     22.000000     16.000000  2.100000e+04
# 50%     2015.000000     26.000000     18.000000  2.999500e+04
# 75%     2016.000000     30.000000     22.000000  4.223125e+04
# max     2017.000000    354.000000    137.000000  2.065902e+06

# %%
numericfeatures_df.corr()
# Out:
# C:\Users\konda\AppData\Local\Temp\ipykernel_32652\2862831947.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   numericfeatures_df.corr()
#                  year  highway_mpg  city_mpg     price
# year         1.000000     0.258240  0.198171  0.227590
# highway_mpg  0.258240     1.000000  0.886829 -0.160043
# city_mpg     0.198171     0.886829  1.000000 -0.157676
# price        0.227590    -0.160043 -0.157676  1.000000

# %%
numericfeatures_df.corr().unstack().sort_values(ascending = False)[:15]
# Out:
# C:\Users\konda\AppData\Local\Temp\ipykernel_32652\3493037483.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   numericfeatures_df.corr().unstack().sort_values(ascending = False)[:15]
# year         year           1.000000
# highway_mpg  highway_mpg    1.000000
# city_mpg     city_mpg       1.000000
# price        price          1.000000
# highway_mpg  city_mpg       0.886829
# city_mpg     highway_mpg    0.886829
# year         highway_mpg    0.258240
# highway_mpg  year           0.258240
# year         price          0.227590
# price        year           0.227590
# year         city_mpg       0.198171
# city_mpg     year           0.198171
#              price         -0.157676
# price        city_mpg      -0.157676
# highway_mpg  price         -0.160043
# dtype: float64

# %%
df1 = df.copy()
mean = df1['price'].mean()
df1['above_average'] = np.where(df['price']>=mean,1,0)

# %%
df1 = df1.drop('price',axis=1)

# %%
df_train_full, df_test = train_test_split(df1, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.above_average.values
y_val = df_val.above_average.values
y_test = df_test.above_average.values

# %%
catvar = ['make','model','transmission_type','vehicle_style']

# %%
def calculate_mi(series):
    return mutual_info_score(series, df_train.above_average)


df_mi = df_train[catvar].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')
df_mi
# Out:
#                          MI
# model              0.462344
# make               0.239769
# vehicle_style      0.084143
# transmission_type  0.020958

# %%
df_train = df_train.drop('above_average', axis=1)
df_val = df_val.drop('above_average', axis=1)
df_test = df_test.drop('above_average', axis=1)

# %%
numvar = ["year","highway_mpg","city_mpg","engine_hp"]
train_dict = df_train[catvar + numvar].to_dict(orient='records')
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)
X_train = dv.transform(train_dict)

# %%
model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)

val_dict = df_val[catvar + numvar].to_dict(orient='records')
X_val = dv.transform(val_dict)
y_pred = model.predict(X_val)

accuracy = np.round(accuracy_score(y_val, y_pred),2)
print(accuracy)
# Out:
# 0.94

# %%
features = catvar + numvar
features
# Out:
# ['make',
#  'model',
#  'transmission_type',
#  'vehicle_style',
#  'year',
#  'highway_mpg',
#  'city_mpg',
#  'engine_hp']

# %%
orig_score = accuracy

for c in features:
    subset = features.copy()
    subset.remove(c)
    
    train_dict = df_train[subset].to_dict(orient='records')

    dv = DictVectorizer(sparse=False)
    dv.fit(train_dict)

    X_train = dv.transform(train_dict)

    model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    val_dict = df_val[subset].to_dict(orient='records')
    X_val = dv.transform(val_dict)

    y_pred = model.predict(X_val)

    score = accuracy_score(y_val, y_pred)
    print(c, orig_score - score, score)
# Out:
# make 0.014695761644985206 0.9253042383550147
# model 0.017633235417540916 0.922366764582459
# transmission_type 0.014695761644985206 0.9253042383550147
# vehicle_style -0.0012505245488879657 0.9412505245488879
# year -0.006286193873269008 0.946286193873269
# highway_mpg -0.005027276542173831 0.9450272765421738
# city_mpg -0.0041879983214435645 0.9441879983214435
# engine_hp 0.03693663449433482 0.9030633655056651

# %%
df['price']=np.log1p(df['price'])

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.price.values
y_val = df_val.price.values
y_test = df_test.price.values

# %%
del df_train['price']
del df_val['price']
del df_test['price']

# %%
train_dict = df_train[catvar + numvar].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=True)
dv.fit(train_dict)

X_train = dv.transform(train_dict)

val_dict = df_val[catvar + numvar].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
for a in [0, 0.01, 0.1, 1, 10]:
    model = Ridge(alpha=a, solver="sag", random_state=42)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    score = np.sqrt(mean_squared_error(y_val, y_pred))
    print(a, round(score, 4))
# Out:
# 0 0.2563
# 0.01 0.247
# 0.1 0.2518
# 1 0.275
# 10 0.3403

# %%
# Out:
# 10 0.3468
